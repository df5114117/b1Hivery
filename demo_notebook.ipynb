# %%
from main import model
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
m = model()
data  = pd.read_csv('example.csv')
m.setData(data)
m.preprocessData()
m.generateSimilarityMatrix()
m.generateClusters()
# Out:
# [('Coke', 1), ('water', 2), ('Pepsi', 1), ('beer ', 0), ('fanta', 1), ('sprite', 1)]

# %%
print(m.getData())
# Out:
# [[0.15384615 0.2        0.15625    0.15384615 0.15625    0.15625   ]
#  [0.15384615 0.2        0.15625    0.23076923 0.15625    0.15625   ]
#  [0.38461538 0.2        0.375      0.15384615 0.359375   0.34375   ]
#  [0.15384615 0.2        0.15625    0.30769231 0.171875   0.1875    ]
#  [0.15384615 0.2        0.15625    0.15384615 0.15625    0.15625   ]]

# %%
print(m.getSimilarityMatrix())
# Out:
# [[0.         0.36923077 0.01923077 0.46153846 0.05048077 0.08173077]
#  [0.36923077 0.         0.35       0.27692308 0.31875    0.2875    ]
#  [0.01923077 0.35       0.         0.45192308 0.03125    0.0625    ]
#  [0.46153846 0.27692308 0.45192308 0.         0.42067308 0.38942308]
#  [0.05048077 0.31875    0.03125    0.42067308 0.         0.03125   ]
#  [0.08173077 0.2875     0.0625     0.38942308 0.03125    0.        ]]

# %%
reduced = m.reduceDimensionality()
plt.scatter(reduced[:,0],reduced[:,1])
# Out:
# <img src="data:image/png;base64,..." width="640">
